# %% [markdown]
# # HW2 - Syllabus Parsing
# ## Christopher Chao

# %%
import pandas as pd
import re
import pdfplumber
import os

# %% [markdown]
# # IMPORTANT! Change to the directory of the syllabi folder location

# %%
#Change this to the directory of the syllabi folder location
directory = os.fsencode('D:/Dropbox/School/20-21 S2/Data Wrangling/HW 2/syllabi')

# %% [markdown]
# # Testing PDF to Text Package (pdfplumber)

# %%
pdf = pdfplumber.open('syllabi/Syllabus_Sample.pdf')
page = pdf.pages[0]
text = page.extract_text()
#print(text)
pdf.close()

# %% [markdown]
# # Retrieving All Syllabi and Saving Text As List
# * `list_of_syllabi` contains all the syllabi, each element is a syllabus.
# * Each element of `list_of_syllabi` is a list called `page_list`.
# * Each element of `page_list` is a page of the pdf file converted to text. <br> <br>
# It should look like the format: <br>
# `[[Syllabus1_Page1, Syllabus1_Page2,...],[Syllabus2_Page1, Syllabus2_Page2,...]]`

# %% [markdown]
# ## This cell will take a while to run, since it is reading through all syllabi and appending it to a list.

# %%
list_of_syllabi = []
num_of_pdf = 0

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    
    page_list = []
    
    if filename.endswith(".pdf"):
        num_of_pdf += 1
        pdf = pdfplumber.open('syllabi/' + filename)

        pages = pdf.pages
        
        for i,pg in enumerate(pages):
            text = pages[i].extract_text()
            page_list.append(text)
            

        pdf.close()
        
        #print(page_list)
    else:
        continue
    list_of_syllabi.append(page_list)

# %%
num_of_pdf
# Out:
# 31

# %%
#Prints out Syllabus 1's First Page
list_of_syllabi[0][0]
# Out:
# 'ENG 439 Syllabus 1 \nENG 439-001: Advanced Grammar Syllabus \nDepartment of English, SFASU \nFall 2016 \nTR 12:30-1:45  p.m. \nF182 \n \nProfessor:    Dr. Jessie Sams \nOffice:    LAN 229 \nOffice hours:  TR 3:15-4:45  p.m. \n      F 12:50-2:50  p.m. \n      Finals week office hours: WR 1:00-2:30 p.m. \nEmail:    samsj@sfasu.edu \nTumblr:    http://jessiesams.tumblr.com \n \nTextbook:    All readings for the semester will be supplied as PDFs on our course’s D2L site. You \nneed to have these readings accessible during class—whether you print them out or \nbring a device/laptop on which to access them. If you choose to access them on a \ndevice/laptop, download the PDF prior to class so that you do not need to wait on D2L \nor wi-fi during class time. \n \nCourse description \nAdvanced investigation  of the concepts of grammatical form and function, including  the application of \nlabels such as noun, adjective, verb, subject, object, phrase, clause. Study will also include discussion of \nthe use of grammar in written and spoken language, the teaching of grammar in classrooms, the debates \nabout grammatical change in current language, and the notion of standard language. \n \nDepartment objectives \n1.  Develop students’ practical skills in reading, writing, and reasoning, and research skills in \ntraditional print as well as electronic sources. \n2.  Enable students to think critically and analytically,  and to communicate effectively in a variety of \ncontexts. \n3.  Promote students’ understanding of literary and cultural history. \n4.  Empower students to understand and write about texts, as well as produce original  texts. \n5.  Train students to apply the skills they have learned in the discipline to a variety of situations. \n \nCourse objectives \n1.  Encourage students to think about the nature of English studies as a discipline,  leading to a variety \nof professional opportunities,  and about the field’s various critical and pedagogical strategies. \n2.  Instill an awareness of English studies as a diverse and dynamic field which includes writing, \nlinguistics,  literature in translation, and culturally diverse texts in World, British, and American \nliterature. \n \nProgram Learning Outcomes \n1.  The student will demonstrate the ability to think critically and perform close readings of linguistic-\nrelated texts. \n2.  The student will demonstrate the ability to comprehend and apply both traditional and contemporary \nmethods in linguistics to language. \n3.  The student will demonstrate the ability to integrate theories and methodologies  of the linguistics \ncourse with that of other disciplines  taught at the university. \n4.  The student will demonstrate the ability to perform original research and/or data analysis relevant to \nlinguistic  study. '

# %% [markdown]
# ## This massive cell uses regex to find information and add it to a new list

# %%
list_of_syllabi_parsed = []

#Most of the regex is found here
instructor_re = re.compile(r'(?i)(?<=Instructor).{100}|(?<=Professor).{100}',re.DOTALL)
course_re = re.compile(r'(?i)(?<=Course).{100}',re.DOTALL)
units_re = re.compile(r'(?i).{2}(?=unit[s]?[-]?).{50}|.{2}(?= credits).{50}',re.DOTALL)
office_re = re.compile(r'(?i)(?<=Office Hours).{200}',re.DOTALL)
name_re = re.compile(r'([A-Z]{1}[a-z]{1,30}[- ]{0,1}|[A-Z]{1}[- \']{1}[A-Z]{0,1}[a-z]{1,30}[- ]{0,1}){2,3}',re.DOTALL)
email_re = re.compile(r'(?:[A-Za-z0-9!#$%&\'*+\=?^_`{|}~-]+(?:\.[A-Za-z0-9!#$%&\'*+\=?^_`{|}~-]+)*|"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*")@(?:(?:[A-Za-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])')
phone_re = re.compile(r'\(?\d{3}\)?[\s.-]?\d{3}[-]\d{4}|\d{3}[-]\d{4}')
time_re = re.compile(r'[0-2]?[0-9]:[0-5][0-9]')
timeto_re = re.compile(r'[0-2]?[0-9]:[0-5][0-9][am|pm]?[\s]?-[\s]?[0-2]?[0-9]:[0-5][0-9][am|pm]?')
digit_re = re.compile(r'[0-9]')
days_re = re.compile(r'(?i)((mon|tues|wed(nes)?|thur(s)?|fri|sat(ur)?|sun)(day)?)')
year_re = re.compile(r'(20|19)[0-9][0-9]')
classid_re = re.compile(r'[A-Z]{3,5}[\s_]?[0-9]{2,5}')

for i in range(num_of_pdf):
    #Joins all the pages of the PDF into one giant text.
    joined_pages_syllabus = " ".join(list_of_syllabi[i])
    
    name = name_re.search(joined_pages_syllabus)
    email = email_re.search(joined_pages_syllabus)
    phone = phone_re.search(joined_pages_syllabus)
    time = time_re.search(joined_pages_syllabus)
    class_time = timeto_re.search(joined_pages_syllabus)
    day = days_re.search(joined_pages_syllabus)
    year = year_re.search(joined_pages_syllabus)
    ID = classid_re.search(joined_pages_syllabus)
    
    #This list will store all the information
    current_syllabus = []
    
    #Divider line
    #print('==========================================')
    
#Course Name
    try:
        after_course = course_re.search(joined_pages_syllabus).group(0)
        course_name = name_re.search(after_course).group(0)
        #print("Course Name: " + course_name)
        current_syllabus.append(course_name)
    except: 
        #print("Course Name Unavailable.")
        current_syllabus.append("")
    
#Course ID
    try:
        #print("CourseID: " + ID.group(0))
        current_syllabus.append(ID.group(0))        
    except: 
        #print("Course ID Unavailable.")
        current_syllabus.append("")
    
#Unit Count
    try:
        after_units = units_re.search(joined_pages_syllabus).group(0)
        unit_count = digit_re.search(after_units).group(0)
        #print("Units: " + unit_count)
        current_syllabus.append(unit_count)
    except: 
        #print("Unit Count Unavailable.")
        current_syllabus.append("")
            
#Instructor Name
    try:
        after_instructor = instructor_re.search(joined_pages_syllabus).group(0)
        instructor_name = name_re.search(after_instructor).group(0)
        #print("Instructor Name: " + instructor_name.strip())
        current_syllabus.append(instructor_name.strip())
    except: 
        #print("Instructor Name Unavailable.")
        current_syllabus.append("")
    
#Office Hours
    try:
        after_office = office_re.search(joined_pages_syllabus).group(0)
        office_hours = time_re.search(after_office).group(0)
        #print("Office Hours: " + office_hours)
        current_syllabus.append(office_hours)
    except: 
        #print("Office Hours Unavailable.")
        current_syllabus.append("")
    
#Email
    try:
        #print("Email: " + email.group(0))
        current_syllabus.append(email.group(0))
    except:
        #print("Email Unavailable.")
        current_syllabus.append("")
    
#Phone Number
    try:
        #print("Phone: " + phone.group(0))
        current_syllabus.append(phone.group(0))
    except:
        #print("Phone Number Unavailable.")
        current_syllabus.append("")
    
#Day
    try:
        #print("Day: " + day.group(0).capitalize())
        current_syllabus.append(day.group(0).capitalize())
    except: 
        #print("Day Unavailable.")
        current_syllabus.append("")
    
#Time
    try:
        #print("Class starts at: " + class_time.group(0))
        current_syllabus.append(class_time.group(0))
    except:
        #print("Time Unavailable.")
        current_syllabus.append("")

#Semester
    if (re.compile(r'(?i)Fall').search(joined_pages_syllabus) is not None):
        #print("Semester: Fall")
        current_syllabus.append("Fall")
    elif (re.compile(r'(?i)Spring').search(joined_pages_syllabus) is not None):
        #print("Semester: Spring")
        current_syllabus.append("Spring")
    elif (re.compile(r'(?i)Winter').search(joined_pages_syllabus) is not None):
        #print("Semester: Winter")
        current_syllabus.append("Winter")
    elif (re.compile(r'(?i)Summer').search(joined_pages_syllabus) is not None):
        #print("Semester: Summer")
        current_syllabus.append("Summer")
    else:
        #print("Semester Unavailable.")
        current_syllabus.append("")
    
#Year
    try:
        #print("Year: " + year.group(0))
        current_syllabus.append(year.group(0))
    except:
        #print("Year Unavailable.")
        current_syllabus.append("")

#Online
    if (re.compile(r'(?i)Online').search(joined_pages_syllabus) is not None):
        #print("Online: Yes")
        current_syllabus.append("Yes")
    else:
        #print("Online: No")
        current_syllabus.append("No")
        
    list_of_syllabi_parsed.append(current_syllabus)

# %% [markdown]
# ## First 2 elements of the parsed list

# %%
list_of_syllabi_parsed[0:2]
# Out:
# [['',
#   'ENG 439',
#   '',
#   'Jessie Sams',
#   '3:15',
#   'samsj@sfasu.edu',
#   '468-3004',
#   'Mon',
#   '12:30-1:45',
#   'Fall',
#   '2016',
#   'No'],
#  ['',
#   'BIOL 175',
#   '5',
#   'Zach Stahlschmidt',
#   '2:00',
#   'zstahlschmidt@pacific.edu',
#   '(209) 946-3021',
#   'Wed',
#   '11:00a -12:15p',
#   'Fall',
#   '2019',
#   'No']]

# %% [markdown]
# ## Generating a Pandas dataframe of the parsed syllabi

# %%
syllabi_parsed_df = pd.DataFrame(list_of_syllabi_parsed, columns = ['Course Name', 'Course ID', 'Units',
                                                                    'Instructor Name', 'Office Hours', 'Email',
                                                                    'Phone', 'Day', 'Class Time',
                                                                    'Semester', 'Year', 'Online'])
syllabi_parsed_df
# Out:
#                  Course Name  Course ID Units          Instructor Name  \
# 0                               ENG 439                    Jessie Sams
# 1                              BIOL 175     5        Zach Stahlschmidt
# 2                              BIOL_193                    Doug Risser
# 3              Course Title     CGS1000     2        College Computing
# 4                              CHEM 121
# 5                             COMM 5300     8            Glen Feighery
# 6                                           4             Virtual Offi
# 7            Sharon Simmons                             Sharon Simmons
# 8                              CAS\t522
# 9            Class Overview   SSMS 4409                     Ziad Matni
# 10      Contact Information                 4       Professor Ferguson
# 11               Body System   BIOL 145             Joan Lin-Cereghino
# 12                              SOC 399            Laurie Cooper Stoll
# 13                             EXAM 200     3             Office Hours
# 14                            ISTRY 101     2            Timothy Welsh
# 15                                                     Andrew Davidson
# 16  Supply Chain Management    TRA 6157                   Robb Frankel
# 17                             PSYC 348               Catherine Rabadi
# 18           Course Syllabus    CIS1254     3         Anedria Williams
# 19                            CHEM 4461
# 20                             INFO 200     2            Molly Johnson
# 21      Computer Programming                          Andisheh Dadashi
# 22       Analytics Computing   ANLT 212     2  Instructor Email Office
# 23              Data Science   COMP 061     4  Instructor Email Office
# 24         Software Methods    ANLT 210                  James Hetrick
# 25                                          5         Binod Nainabasti
# 26            Human Anatomy   BIOSC 047     5           Jenny Fichmann
# 27                             JGEN 300                       John Doe
# 28     Time Series Analysis                 1              Art Telkamp
# 29                            MCOM 3370                 Vanessa Joyner
# 30           Course Syllabus    CTS2327     3         Patti Keefe West
#
#    Office Hours                              Email           Phone        Day  \
# 0          3:15                    samsj@sfasu.edu        468-3004        Mon
# 1          2:00          zstahlschmidt@pacific.edu  (209) 946-3021        Wed
# 2          1:00                drisser@pacific.edu        932-2953    Tuesday
# 3          6:00          Adam.Jordan@sfcollege.edu    352-395-4400  Wednesday
# 4          5:00                   lxue@pacific.edu  (209) 946-2360        Mon
# 5                           glen.feighery@utah.edu    801-581-5020  Wednesday
# 6          8:20             garciacr@lamission.edu  (818) 364-7600      Thurs
# 7                                 simmonsj@jmu.edu    540-568-4196        Sat
# 8                                    dgs@cs.bu.edu                        Wed
# 9         10:00                 zmatni@cs.ucsb.edu        978-0134        Wed
# 10         4:30           nadine.ferguson@sjsu.edu    408-924-7171    Tuesday
# 11        10:30               jlincere@pacific.edu        946-2988    Tuesday
# 12        12:30                  lcstoll@uwlax.edu    608-785-8664    Tuesday
# 13        10:30           Mohammad.Saleem@sjsu.edu    408-924-5141  Wednesday
# 14                 timothywelsh@ventureacademy.edu    209-958-3232  Wednesday
# 15                   ahdavidson@seattleschools.org                        Mon
# 16         2:00                   ybolumol@unf.edu    904-620-2769     Monday
# 17                          crabadi@bridgeport.edu  (855) 333-8248        Mon
# 18                  anedria.williams@sfcollege.edu    352-575-9881        Mon
# 19                                  kschug@uta.edu    817-272-3541        Mon
# 20                               mjohnson@sjsu.edu    209-862-2011        Mon
# 21                                andisheh@unm.edu        119-4985        Mon
# 22                            dnehoran@pacific.edu  (209) 946-3221  Wednesday
# 23                            dnehoran@pacific.edu    209-946-3221        Mon
# 24                            jhetrick@pacific.edu    209-518-7835        Mon
# 25         8:00            bnainabasti@pacific.edu    209-946-3221        Wed
# 26        11:30  jenny.fichmann@missioncollege.edu   (408-855-5085  Wednesday
# 27        12:30                   jdoe1@alltel.net        472-6031    Tuesday
# 28                            atelkamp@pacific.edu    949-422-5338        Wed
# 29         2:00                vjoyner@uttyler.edu  (903) 565-5555  Wednesday
# 30         7:43          patti.keefe@sfcollege.edu    352-395-5797        Mon
#
#         Class Time Semester  Year Online
# 0       12:30-1:45     Fall  2016     No
# 1   11:00a -12:15p     Fall  2019     No
# 2      10:00-11:45   Spring  2019    Yes
# 3                    Spring  2021    Yes
# 4                      Fall  2016     No
# 5                    Spring  2021    Yes
# 6                      Fall  2020    Yes
# 7                      Fall  2020    Yes
# 8      10:10-11:00   Spring  2021    Yes
# 9                      Fall  2017    Yes
# 10     3:00 - 4:15   Spring  2019     No
# 11       8:00-9:45     Fall  2016    Yes
# 12       2:15-3:40   Spring  2019     No
# 13                   Spring  2017     No
# 14                     Fall  2016     No
# 15                                   Yes
# 16                     Fall  2008    Yes
# 17                     Fall  2012    Yes
# 18                   Spring  2021    Yes
# 19                   Spring  2020    Yes
# 20                   Spring  2021    Yes
# 21                   Spring  2020    Yes
# 22                     Fall  2020    Yes
# 23                     Fall  2019    Yes
# 24                   Spring  2020     No
# 25      8:00 -9:30     Fall  2018    Yes
# 26     12:40-2:05p     Fall  2018     No
# 27       8:00-9:30     Fall  2007     No
# 28   18:00 - 20:00   Spring  2021    Yes
# 29                     Fall  2018     No
# 30                   Spring  2020    Yes

# %%
syllabi_parsed_df.to_csv('features-retrieved-by-ChrisChao.csv')
